# %% [markdown]
# <a href="https://colab.research.google.com/github/Nevethawei/my-first-code/blob/main/Sentiment_Analysis_Model_using_an_LSTM_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from keras.datasets import imdb
from keras.models import Sequential
from keras.layers import Embedding, LSTM, Dense
from keras.preprocessing.sequence import pad_sequences

# Parameters
vocab_size = 10000   # Top 10k words
maxlen = 200         # Max length of review
embedding_dim = 128

# Load IMDB dataset
(X_train, y_train), (X_test, y_test) = imdb.load_data(num_words=vocab_size)

# Pad sequences to make equal length
X_train = pad_sequences(X_train, maxlen=maxlen)
X_test = pad_sequences(X_test, maxlen=maxlen)

# Build LSTM Model
model = Sequential()
model.add(Embedding(vocab_size, embedding_dim, input_length=maxlen))
model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))

# Compile
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

# Train
model.fit(X_train, y_train, batch_size=64, epochs=3, validation_data=(X_test, y_test))

# Evaluate
loss, acc = model.evaluate(X_test, y_test, verbose=0)
print(f"Test Accuracy: {acc * 100:.2f}%")
# Out:
# Epoch 1/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 168s 423ms/step - accuracy: 0.7031 - loss: 0.5517 - val_accuracy: 0.8167 - val_loss: 0.4091
# Epoch 2/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 194s 404ms/step - accuracy: 0.8580 - loss: 0.3372 - val_accuracy: 0.8407 - val_loss: 0.3647
# Epoch 3/3
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 201s 403ms/step - accuracy: 0.8870 - loss: 0.2791 - val_accuracy: 0.8594 - val_loss: 0.3424
# Test Accuracy: 85.94%
