# %% [markdown]
# <a href="https://colab.research.google.com/github/Nevethawei/my-first-code/blob/main/map%2C_graphic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import matplotlib.pyplot as plt
data = [[12, 18],
        [5,  20]]
sns.heatmap(data, annot=True, cmap="Reds")
plt.title("Low Student Scores")
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [50, 55, 53, 60, 65]
sns.lineplot(x=x, y=y)
plt.title("Daily Sales")
plt.xlabel("Day")
plt.ylabel("Sales")
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
data = [12,34,21,31,23,35,25,51,55]
fig, axes = plt.subplots(1, 2, figsize=(10, 4))
sns.histplot(data, bins=5, ax=axes[0], color='skyblue')
axes[0].set_title("Histogram")
sns.kdeplot(data, ax=axes[1], color='green', fill=True)
axes[1].set_title("KDE Plot")

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
x = [1, 2, 3, 4, 5]
y = [10, 15, 13, 18, 16]
plt.plot(x, y, color='purple')
plt.title("Simple Line Chart")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
import matplotlib.pyplot as plt
labels = ['Apples', 'Bananas', 'Cherries', 'Dates']
sizes = [25, 35, 20, 20]
colors = ['blue', 'yellow', 'red', 'brown']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%')
plt.title("Fruit Distribution")
plt.show()

# %%
import matplotlib.pyplot as plt
labels = ['Apple', 'Banana', 'orange', 'Date']
sizes = [30, 25, 25, 20]
colors = ['red','yellow','orange','brown']
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', wedgeprops={'width': 0.4})
plt.title('Fruit Preference')
plt.show()
